# %%
# %load_ext rpy2.ipython

# %%
# don't need to install if on collab
# %%R
install.packages("caret")
install.packages("e1071")
install.packages("randomForest")
install.packages("rpart")
install.packages("rpart.plot")
install.packages("tidyverse")
install.packages("ggplot2")

# %%
# %%R
# install.packages("caret")
# Out:
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: also installing the dependencies ‘listenv’, ‘parallelly’, ‘future’, ‘globals’, ‘shape’, ‘future.apply’, ‘numDeriv’, ‘progressr’, ‘SQUAREM’, ‘diagram’, ‘lava’, ‘prodlim’, ‘proxy’, ‘iterators’, ‘clock’, ‘gower’, ‘hardhat’, ‘ipred’, ‘timeDate’, ‘e1071’, ‘foreach’, ‘ModelMetrics’, ‘plyr’, ‘pROC’, ‘recipes’, ‘reshape2’
#
#
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: trying URL 'https://cran.rstudio.com/src/contrib/listenv_0.9.1.tar.gz'
#
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: Content type 'application/x-gzip'
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]:  length 36600 bytes (35 KB)
#
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# ...

# %%
# %%R
#
# library(caret)
# library(e1071)
# library(randomForest)
# library(rpart)
# library(rpart.plot)
# library(tidyverse)
# library(ggplot2)
# Out:
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: Error in library(caret) : there is no package called ‘caret’
# Error in library(caret) : there is no package called ‘caret’

# %%
# %%R
# # Load the dataset
# data <- read.csv("recruitment_data.csv")

# %%
# %%R
# # Data Understanding
# str(data)
# summary(data)
# Out:
# 'data.frame':	1500 obs. of  11 variables:
#  $ Age                : int  26 39 48 34 30 27 48 40 26 45 ...
#  $ Gender             : int  1 1 0 1 0 0 0 0 1 1 ...
#  $ EducationLevel     : int  2 4 2 2 1 3 2 4 3 2 ...
#  $ ExperienceYears    : int  0 12 3 5 6 14 6 13 6 2 ...
#  $ PreviousCompanies  : int  3 3 2 2 1 4 1 3 5 5 ...
#  $ DistanceFromCompany: num  26.78 25.86 9.92 6.41 43.11 ...
#  $ InterviewScore     : int  48 35 20 36 23 54 24 6 80 92 ...
#  $ SkillScore         : int  78 68 67 27 52 50 52 3 78 16 ...
#  $ PersonalityScore   : int  91 80 13 70 85 50 64 92 51 94 ...
#  $ RecruitmentStrategy: int  1 2 2 3 2 1 3 3 1 3 ...
#  $ HiringDecision     : int  1 1 0 0 0 1 0 0 1 0 ...
#       Age            Gender      EducationLevel  ExperienceYears
#  Min.   :20.00   Min.   :0.000   Min.   :1.000   Min.   : 0.000
#  1st Qu.:27.00   1st Qu.:0.000   1st Qu.:2.000   1st Qu.: 4.000
#  Median :35.00   Median :0.000   Median :2.000   Median : 8.000
# ...

# %%
# %%R
#
# # Convert categorical variables to factors
# data$Gender <- as.factor(data$Gender)
# data$EducationLevel <- as.factor(data$EducationLevel)
# data$RecruitmentStrategy <- as.factor(data$RecruitmentStrategy)
# data$HiringDecision <- as.factor(data$HiringDecision)

# %%
# %%R
# # Convert categorical variables to factors
# data$Gender <- as.factor(data$Gender)
# data$EducationLevel <- as.factor(data$EducationLevel)
# data$RecruitmentStrategy <- as.factor(data$RecruitmentStrategy)
# data$HiringDecision <- as.factor(data$HiringDecision)

# %%
# %%R
#
# # Exploratory Data Analysis
# # Plot distribution of target variable
# ggplot(data, aes(x = HiringDecision)) +
#     geom_bar() +
#     ggtitle("Distribution of Hiring Decision")

# %%
# %%R
# # Exploratory Data Analysis
# # Plot distribution of target variable
# ggplot(data, aes(x = HiringDecision)) +
#     geom_bar() +
#     ggtitle("Distribution of Hiring Decision")

# %%
# %%R
# # Plot relationships between features and target
# ggplot(data, aes(x = Gender, fill = HiringDecision)) +
#     geom_bar(position = "fill") +
#     ggtitle("Gender vs Hiring Decision")

# %%
# %%R
# ggplot(data, aes(x = EducationLevel, fill = HiringDecision)) +
#     geom_bar(position = "fill") +
#     ggtitle("Education Level vs Hiring Decision")

# %%
# %%R
# # Modeling
# # Logistic Regression
# log_model <- glm(HiringDecision ~ ., data = trainData, family = binomial)
# log_pred <- predict(log_model, newdata = testData, type = "response")
# log_pred_class <- ifelse(log_pred > 0.5, 1, 0)
# log_conf <- confusionMatrix(as.factor(log_pred_class), testData$HiringDecision)
# log_conf
# Out:
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: Error in eval(mf, parent.frame()) : object 'trainData' not found
# Error in eval(mf, parent.frame()) : object 'trainData' not found

# %%
# %%R
